# %% [markdown]
# <div style="text-align: center; padding: 20px; border-radius: 10px;">
#     <h1 style="color: #ffffff; font-size: 36px; font-weight: bold; text-shadow: 2px 2px 4px #3498db;">📊 INTC Stock Price Analysis 📈</h1>
#     <p style="font-size: 18px; color: #7f8c8d;">Exploring Market Trends Through Big Data and Machine Learning</p>
# </div>

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 24px;
#     font-weight: bold;
#     text-shadow: 4px 4px 10px rgba(52, 152, 219, 0.8);
#     color: #ffffff;">
#     Group Identification:
# </div>
#
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 16px;
#     font-weight: bold;
#     width: 95%;
#     color: #ffffff;
#     padding: 10px 15px;
#     border-radius: 5px;
#     display: inline-block;
#     margin: 10px">
#     <strong>GROUP NUMBER: <span style="text-align: center; color: #ffffff; font-weight: bold;">06</span></strong>
# </div>
#
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 16px;
#     font-weight: bold;
#     width: 95%;
#     color: #ffffff;
#     padding: 10px 15px;
#     border-radius: 5px;
#     display: inline-block;
#     margin: 10px">
#     <strong>GROUP MEMBERS:</strong>
# </div>
#
# <table style="
#     width: 60%;
#     margin: 20px auto;
#     border-collapse: collapse;
#     font-family: Arial, sans-serif;
#     font-size: 16px;
#     color: #2c3e50;
#     border-radius: 8px;
#     box-shadow: 0px 2px 8px rgba(0, 0, 0, 0.1);">
# <tr style="
#         background-color: #e0e0e0;
#         color: #2c3e50;
#         font-weight: bold;
#         text-align: center;">
#         <th style="padding: 12px; border-bottom: 2px solid #b0b0b0;">STUDENT NAME</th>
#         <th style="padding: 12px; border-bottom: 2px solid #b0b0b0;">STUDENT NUMBER</th>
# </tr>
#
# <tr style="background-color: #f9f9f9; text-align: center;">
#         <td style="padding: 12px; border-bottom: 1px solid #d0d0d0;">Tiago Pedro Soares</td>
#         <td style="padding: 12px; border-bottom: 1px solid #d0d0d0;">20240655</td>
# </tr>
# <tr style="background-color: #f9f9f9; text-align: center;">
#         <td style="padding: 12px; border-bottom: 1px solid #d0d0d0;">Bráulio Damba</td>
#         <td style="padding: 12px; border-bottom: 1px solid #d0d0d0;">XXXXXXXX</td>
# </tr>
# <tr style="background-color: #f9f9f9; text-align: center;">
#         <td style="padding: 12px; border-bottom: 1px solid #d0d0d0;">Rui Lourenço</td>
#         <td style="padding: 12px; border-bottom: 1px solid #d0d0d0;">XXXXXXXX</td>
# </tr>
# <tr style="background-color: #f9f9f9; text-align: center;">
#         <td style="padding: 12px; border-bottom: 1px solid #d0d0d0;">Victoria Goon</td>
#         <td style="padding: 12px; border-bottom: 1px solid #d0d0d0;">XXXXXXXX</td>
# </tr>
# <tr style="background-color: #f9f9f9; text-align: center;">
#         <td style="padding: 12px; border-bottom: 1px solid #d0d0d0;">Mariana Sousa</td>
#         <td style="padding: 12px; border-bottom: 1px solid #d0d0d0;">XXXXXXXX</td>
# </tr>
# </table>

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 24px;
#     font-weight: bold;
#     text-shadow: 4px 4px 10px rgba(52, 152, 219, 0.8);
#     color: #ffffff;">
#     PACKAGES
# </div>

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 18px;
#     font-weight: bold;
#     width: 95%;
#     color: #ffffff;
#     background-color: #1f8a5b;
#     padding: 10px 15px;
#     border-radius: 5px;
#     display: inline-block;
#     margin: 10px">
#     <strong>Now we gonna import all the packages that we need to extract the database</strong>
# </div>

# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.abspath(".."))
from src import init_import_data

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 24px;
#     font-weight: bold;
#     text-shadow: 4px 4px 10px rgba(52, 152, 219, 0.8);
#     color: #ffffff;">
#     INITIALIZATION PROCESS OF IMPORTING THE DATA
# </div>

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 18px;
#     font-weight: bold;
#     width: 95%;
#     color: #ffffff;
#     background-color: #1f8a5b;
#     padding: 10px 15px;
#     border-radius: 5px;
#     display: inline-block;
#     margin: 10px">
#     <strong>Importing the database for the project</strong>
# </div>

# %%
periods = {
    "before_trump": (pd.to_datetime("1999-01-20"), pd.to_datetime("2017-01-20")),
    "during_trump": (pd.to_datetime("2017-01-20"), pd.to_datetime("2021-01-20")),
    "after_trump": (pd.to_datetime("2021-01-20"), pd.to_datetime("2025-01-20"))
}

# %%
df = init_import_data("INTC", "1d", periods)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df.columns = pd.MultiIndex.from_tuples(
    [(col[0], 'INTC') if col[1] == '' else col for col in df.columns],
    names=df.columns.names
)

# %%
df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in df.columns]

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 18px;
#     font-weight: bold;
#     width: 95%;
#     color: #ffffff;
#     background-color: #1f8a5b;
#     padding: 10px 15px;
#     border-radius: 5px;
#     display: inline-block;
#     margin: 10px">
#     <strong>Export the database for the project</strong>
# </div>

# %%
df.to_csv("../data/external/intel_stock_data.csv")
