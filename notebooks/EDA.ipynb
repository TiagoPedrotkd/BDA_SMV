# %% [markdown]
# <div style="text-align: center; padding: 20px; border-radius: 10px;">
#     <h1 style="color: #ffffff; font-size: 36px; font-weight: bold; text-shadow: 2px 2px 4px #3498db;">
#         📊🔍 Exploratory Data Analysis (EDA) 📈📉
#     </h1>
# </div>

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 24px;
#     font-weight: bold;
#     text-shadow: 4px 4px 10px rgba(52, 152, 219, 0.8);
#     color: #ffffff;">
#    👤🔍 Group Identification
# </div>
#
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 16px;
#     font-weight: bold;
#     width: 95%;
#     color: #ffffff;
#     padding: 10px 15px;
#     border-radius: 5px;
#     display: inline-block;
#     margin: 10px">
#     <strong>GROUP NUMBER: <span style="text-align: center; color: #ffffff; font-weight: bold;">06</span></strong>
# </div>
#
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 16px;
#     font-weight: bold;
#     width: 95%;
#     color: #ffffff;
#     padding: 10px 15px;
#     border-radius: 5px;
#     display: inline-block;
#     margin: 10px">
#     <strong>GROUP MEMBERS:</strong>
# </div>
#
# <div style="display: flex; justify-content: center; align-items: center; width: 100%;">
#   <table style="width: 80%; border-collapse: collapse; font-size: 16px; color: #ffffff; background: #1e272e; border-radius: 10px; overflow: hidden; text-align: left; box-shadow: 0px 4px 8px rgba(0,0,0,0.2);">
#     <tr style="background: #34495e; color: white;">
#       <th style="padding: 12px; border-bottom: 3px solid #f9f9f9; border-top-left-radius: 10px; border-top-right-radius: 10px;">👤 STUDENT NAME</th>
#       <th style="padding: 12px; border-bottom: 3px solid #f9f9f9;">🆔 STUDENT NUMBER</th>
#     </tr>
#     <tr style="background: #34495e; text-align: center;">
#       <td style="padding: 12px; border-bottom: 1px solid #485b74;">Tiago Pedro Soares</td>
#       <td style="padding: 12px; border-bottom: 1px solid #485b74;">20240655</td>
#     </tr>
#     <tr style="background: #2c3e50; text-align: center;">
#       <td style="padding: 12px; border-bottom: 1px solid #485b74;">Bráulio Damba</td>
#       <td style="padding: 12px; border-bottom: 1px solid #485b74;">20240007</td>
#     </tr>
#     <tr style="background: #34495e; text-align: center;">
#       <td style="padding: 12px; border-bottom: 1px solid #485b74;">Rui Lourenço</td>
#       <td style="padding: 12px; border-bottom: 1px solid #485b74;">XXXXXXXX</td>
#     </tr>
#     <tr style="background: #2c3e50; text-align: center;">
#       <td style="padding: 12px; border-bottom: 1px solid #485b74;">Victoria Goon</td>
#       <td style="padding: 12px; border-bottom: 1px solid #485b74;">20240550</td>
#     </tr>
#     <tr style="background: #34495e; text-align: center;">
#       <td style="padding: 12px; border-bottom: 1px solid #485b74; border-bottom-left-radius: 10px;">Mariana Sousa</td>
#       <td style="padding: 12px; border-bottom: 1px solid #485b74; border-bottom-right-radius: 10px;">20240516</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 24px;
#     font-weight: bold;
#     text-shadow: 4px 4px 10px rgba(52, 152, 219, 0.8);
#     color: #ffffff;">
#    🔍 Overview
# </div>
#
# <p style="padding: 10px; border-radius: 10px; font-size: 16px; color: #7f8c8d;">
#     This project explores the historical stock performance of <code><strong>NVIDIA (NVDA)</strong></code> through a rich set of technical indicators. By analyzing patterns in price movements and market signals, the goal is to identify key periods of volatility and assess how external factors — such as political terms or economic policy shifts — may influence investor sentiment.
# </p>
#
# <p style="padding: 10px; border-radius: 10px; font-size: 16px; color: #7f8c8d;">
#     A central question in this analysis is whether U.S. presidential transitions, particularly Donald Trump’s tenure, had a measurable impact on NVIDIA’s valuation, price volatility, and technical momentum. The study leverages <strong>time series data</strong> enriched with <strong>financial indicators</strong> to support this exploration.
# </p>
#
# <p style="padding: 10px; border-radius: 10px; font-size: 16px; color: #7f8c8d;">
#     The dataset includes key fields such as:
#     <ul style="font-size: 18px; color: #f9f9f9; list-style-type: none; padding-left: 0; margin:30px">
#         <li style="background: #34495e; border-left: 5px solid #0A66C2; padding: 15px 20px; margin-bottom: 10px; border-radius: 5px;">
#             💵 <code>open</code>, <code>high</code>, <code>low</code>, <code>close</code> – Daily stock price data.
#         </li>
#         <li style="background: #34495e; border-left: 5px solid #0A66C2; padding: 15px 20px; margin-bottom: 10px; border-radius: 5px;">
#             📈 <code>RSI_rsi</code>, <code>MACD_macd</code>, <code>STOCH_slow_k</code> – Momentum and trend indicators.
#         </li>
#         <li style="background: #34495e; border-left: 5px solid #0A66C2; padding: 15px 20px; margin-bottom: 10px; border-radius: 5px;">
#             📉 <code>BBANDS_upper_band</code>, <code>BBANDS_lower_band</code> – Volatility indicators from Bollinger Bands.
#         </li>
#         <li style="background: #34495e; border-left: 5px solid #0A66C2; padding: 15px 20px; margin-bottom: 10px; border-radius: 5px;">
#             📊 <code>ATR_atr</code>, <code>ADX_adx</code> – Indicators of price strength and trend volatility.
#         </li>
#         <li style="background: #34495e; border-left: 5px solid #0A66C2; padding: 15px 20px; margin-bottom: 10px; border-radius: 5px;">
#             ⏰ <code>Date</code> and <code>Time</code> – Temporal components for sequencing and analysis across political periods.
#         </li>
#     </ul>
# </p>
#
# <p style="padding: 10px; border-radius: 10px; font-size: 16px; color: #7f8c8d;">
#     Through Exploratory Data Analysis (EDA), the project aims to uncover behavioral trends, volatility patterns, and any structural changes in stock movement that may correlate with the Trump presidency. This foundation will support future forecasting, sentiment analysis, and trading signal evaluation.
# </p>

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 24px;
#     font-weight: bold;
#     text-shadow: 4px 4px 10px rgba(52, 152, 219, 0.8);
#     color: #ffffff;">
#    🎯 Objectives
# </div>
#
# <ul style="font-size: 18px; color: #f9f9f9; list-style-type: none; padding-left: 0;">
#     <li style="background: #34495e; border-left: 5px solid #3498db; padding: 15px 20px; margin-bottom: 10px; border-radius: 5px;">
#         🔍 <strong>Understand Stock Price Trends</strong><br> Analyze the historical stock performance of <code><strong>NVIDIA (NVDA)</strong></code>, <code><strong>Intel (INTC)</strong></code>, and <code><strong>AMD (AMD)</strong></code> to identify patterns, fluctuations, and long-term trends.
#     </li>
#     <li style="background: #34495e; border-left: 5px solid #2ecc71; padding: 15px 20px; margin-bottom: 10px; border-radius: 5px;">
#         📊 <strong>Assess Market Behavior During Political Periods</strong><br> Investigate how stock performance evolved <strong>before, during, and after U.S. presidential transitions</strong>, particularly in response to economic policies and investor sentiment.
#     </li>
#     <li style="background: #34495e; border-left: 5px solid #f1c40f; padding: 15px 20px; margin-bottom: 10px; border-radius: 5px;">
#         💰 <strong>Analyze Fundamental Financial Metrics</strong><br> Examine key financial indicators such as <strong>Market Capitalization, Enterprise Value, P/E Ratios, and Price-to-Sales Ratios</strong>, assessing their correlation with stock price movements.
#     </li>
#     <li style="background: #34495e; border-left: 5px solid #e74c3c; padding: 15px 20px; margin-bottom: 10px; border-radius: 5px;">
#         📈 <strong>Evaluate Volatility & Stock Correlations</strong><br> Determine periods of high volatility, identify major price swings, and explore relationships between <code><strong>NVIDIA (NVDA)</strong></code>, <code><strong>Intel (INTC)</strong></code>, and <code><strong>AMD (AMD)</strong></code> stock trends.
#     </li>
#     <li style="background: #34495e; border-left: 5px solid #9b59b6; padding: 15px 20px; margin-bottom: 10px; border-radius: 5px;">
#         🏦 <strong>Build a Strong Foundation for Predictive Analysis</strong><br> Prepare a <strong>well-structured dataset</strong> enriched with technical and fundamental indicators to support <strong>machine learning models and financial forecasting</strong>.
#     </li>
# </ul>

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 24px;
#     font-weight: bold;
#     text-shadow: 4px 4px 10px rgba(52, 152, 219, 0.8);
#     color: #ffffff;">
#    📂 Packages
# </div>

# %% [markdown]
# <p style="font-size: 18px; color: #f1f1f1; background: #2c3e50; padding: 15px; border-radius: 10px;">
#     📥 <strong>Now we gonna import all the packages that we need to analyze the database</strong>
# </p>

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import last, col, when, isnan, percentile_approx, to_date, year, month, date_trunc, avg, lag, mean, stddev, sum, count, lit, to_timestamp
from pyspark.sql import Row

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import sys

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 24px;
#     font-weight: bold;
#     text-shadow: 4px 4px 10px rgba(52, 152, 219, 0.8);
#     color: #ffffff;">
#    📂 Load & Inspect the Data 🔍
# </div>

# %%
df = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/tiagopedrosoares02@gmail.com/nvda_full_2025_05_21_20250521_125800-1.csv")

df.createOrReplaceTempView("nvidia")

# %% [markdown]
# <p style="font-size: 18px; color: #f1f1f1; background: #2c3e50; padding: 15px; border-radius: 10px;">
#     📥 <strong>Dataset Information</strong>
# </p>
#
# <p style="font-size: 16px; color: #7f8c8d; padding: 15px; border-radius: 10px;">
#     🔍 <strong>Columns and Rows Overview</strong>
# </p>

# %%
nr_columns = len(df.columns)
nr_rows = df.count()

summary_df = spark.createDataFrame([
    Row(Metric="Number of Columns", Value=nr_columns),
    Row(Metric="Number of Rows", Value=nr_rows)
])

display(summary_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Metric</th><th>Value</th></tr></thead><tbody><tr><td>Number of Columns</td><td>21</td></tr><tr><td>Number of Rows</td><td>6979</td></tr></tbody></table></div>

# %% [markdown]
# <p style="font-size: 16px; color: #7f8c8d; padding: 20px; border-radius: 10px;">
#     🔍 <strong>Inspection of the First Few Rows:</strong>
# </p>

# %%
display(df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Date</th><th>Time</th><th>open</th><th>high</th><th>low</th><th>close</th><th>volume</th><th>RSI_rsi</th><th>SMA_sma</th><th>EMA_ema</th><th>MACD_macd</th><th>MACD_macd_signal</th><th>MACD_macd_hist</th><th>STOCH_slow_k</th><th>STOCH_slow_d</th><th>ADX_adx</th><th>CCI_cci</th><th>ATR_atr</th><th>BBANDS_upper_band</th><th>BBANDS_middle_band</th><th>BBANDS_lower_band</th></tr></thead><tbody><tr><td>2023-05-22</td><td>09:30</td><td>30.901</td><td>31.52</td><td>30.68</td><td>31.39513</td><td>145468850.0</td><td>65.79526</td><td>31.31563</td><td>31.27555</td><td>0.47700234</td><td>0.54724325</td><td>-0.070240904</td><td>62.29355</td><td>64.44869</td><td>40.40849</td><td>26.16789</td><td>0.3571965</td><td>32.24575</td><td>31.029557</td><td>29.81337</td></tr><tr><td>2023-05-22</td><td>10:30</td><td>31.395</td><td>31.47</td><td>31.232</td><td>31.35269</td><td>48675280.0</td><td>64.5589</td><td>31.27948</td><td>31.29098</td><td>0.45342475</td><td>0.52847955</td><td>-0.0750548</td><td>58.59662</td><td>61.15217</td><td>37.53837</td><td>42.34475</td><td>0.3486825</td><td>32.18723</td><td>31.10803</td><td>30.02883</td></tr><tr><td>2023-05-22</td><td>11:30</td><td>31.354</td><td>31.3683</td><td>31.183</td><td>31.239</td><td>38064010.0</td><td>61.23924</td><td>31.28781</td><td>31.28058</td><td>0.42071598</td><td>0.50692683</td><td>-0.086210854</td><td>48.69357</td><td>56.52791</td><td>35.0044653</td><td>23.46293</td><td>0.33701252</td><td>32.12167</td><td>31.17018</td><td>30.21869</td></tr><tr><td>2023-05-22</td><td>12:30</td><td>31.236</td><td>31.304</td><td>31.15</td><td>31.2805</td><td>32525600.0</td><td>62.0071993</td><td>31.30287</td><td>31.28057</td><td>0.39360533</td><td>0.48426253</td><td>-0.0906572</td><td>52.30835</td><td>53.19951</td><td>32.7656</td><td>11.077173</td><td>0.32394026</td><td>32.031641</td><td>31.23193</td><td>30.43222</td></tr><tr><td>2023-05-22</td><td>13:30</td><td>31.285</td><td>31.399</td><td>31.284</td><td>31.367</td><td>24437720.0</td><td>63.62503</td><td>31.30076</td><td>31.29785</td><td>0.37477972</td><td>0.46236597</td><td>-0.087586252</td><td>59.84337</td><td>53.6151</td><td>30.52</td><td>30.64264</td><td>0.30926594</td><td>31.90152</td><td>31.29568</td><td>30.68985</td></tr></tbody></table></div>

# %% [markdown]
# <p style="font-size: 16px; color: #7f8c8d; padding: 20px; border-radius: 10px;">
#     🧱 <strong>Check Dataset Structure:</strong>
# </p>

# %%
schema_df = spark.sql("DESCRIBE nvidia")
display(schema_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>Date</td><td>string</td><td>null</td></tr><tr><td>Time</td><td>string</td><td>null</td></tr><tr><td>open</td><td>string</td><td>null</td></tr><tr><td>high</td><td>string</td><td>null</td></tr><tr><td>low</td><td>string</td><td>null</td></tr><tr><td>close</td><td>string</td><td>null</td></tr><tr><td>volume</td><td>string</td><td>null</td></tr><tr><td>RSI_rsi</td><td>string</td><td>null</td></tr><tr><td>SMA_sma</td><td>string</td><td>null</td></tr><tr><td>EMA_ema</td><td>string</td><td>null</td></tr><tr><td>MACD_macd</td><td>string</td><td>null</td></tr><tr><td>MACD_macd_signal</td><td>string</td><td>null</td></tr><tr><td>MACD_macd_hist</td><td>string</td><td>null</td></tr><tr><td>STOCH_slow_k</td><td>string</td><td>null</td></tr><tr><td>STOCH_slow_d</td><td>string</td><td>null</td></tr><tr><td>ADX_adx</td><td>string</td><td>null</td></tr><tr><td>CCI_cci</td><td>string</td><td>null</td></tr><tr><td>ATR_atr</td><td>string</td><td>null</td></tr><tr><td>BBANDS_upper_band</td><td>string</td><td>null</td></tr><tr><td>BBANDS_middle_band</td><td>string</td><td>null</td></tr><tr><td>BBANDS_lower_band</td><td>string</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# <p style="font-size: 16px; color: #7f8c8d; padding: 20px; border-radius: 10px;">
#     🧩 <strong>Check Dataset Missing Values:</strong>
# </p>

# %%
total_rows = df.count()

missing_counts = df.select([
    sum(when(col(c).isNull(), 1).otherwise(0)).alias(c)
    for c in df.columns
])

missing_counts_long = missing_counts.selectExpr(
    "stack({0}, {1}) as (Column, Missing_Values)".format(
        len(df.columns),
        ", ".join([f"'{c}', {c}" for c in df.columns])
    )
)

missing_with_percentage = missing_counts_long.withColumn(
    "Percentage (%)",
    (col("Missing_Values") / total_rows) * 100
)

missing_filtered = missing_with_percentage.filter(col("Missing_Values") > 0)
missing_sorted = missing_filtered.orderBy(col("Percentage (%)").desc())
display(missing_sorted)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Column</th><th>Missing_Values</th><th>Percentage (%)</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# <p style="font-size: 16px; color: #7f8c8d; padding: 20px; border-radius: 10px;">
#     📈 <strong>Visualize Descriptive Statistics:</strong>
# </p>

# %%
display(df.describe().toPandas().set_index('summary').T)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count</th><th>mean</th><th>stddev</th><th>min</th><th>max</th></tr></thead><tbody><tr><td>6979</td><td>null</td><td>null</td><td>2023-05-22</td><td>2025-05-20</td></tr><tr><td>6979</td><td>null</td><td>null</td><td>09:30</td><td>15:59</td></tr><tr><td>6979</td><td>107.27579886047995</td><td>32.40665288813315</td><td>100.11</td><td>99.985</td></tr><tr><td>6979</td><td>107.64929955626275</td><td>32.4197507985944</td><td>100.1241</td><td>99.85</td></tr><tr><td>6979</td><td>106.8775526680648</td><td>32.38168952568972</td><td>100.010002</td><td>99.7301</td></tr><tr><td>6979</td><td>107.27618426950207</td><td>32.40002656829918</td><td>100.00495000000001</td><td>99.99</td></tr><tr><td>6979</td><td>2.6144024958387095E7</td><td>3.735941827252022E7</td><td>0.0</td><td>99911380.0</td></tr><tr><td>6979</td><td>52.74751172384274</td><td>13.365656593724164</td><td>12.19562</td><td>90.33449</td></tr><tr><td>6979</td><td>107.20874788619217</td><td>32.421734990637</td><td>100.031199</td><td>99.9287</td></tr><tr><td>6979</td><td>107.20869855535243</td><td>32.41277889365141</td><td>100.12898</td><td>99.97758999999999</td></tr><tr><td>6979</td><td>0.11891246475818519</td><td>0.9908392681282546</td><td>-0.00015622552</td><td>9.1938322e-05</td></tr><tr><td>6979</td><td>0.1190271470653549</td><td>0.9270218029280051</td><td>-0.00010669037</td><td>7.591117e-06</td></tr><tr><td>6979</td><td>-1.1472255082831759E-4</td><td>0.3015489720162258</td><td>-0.00013873425</td><td>9.5376712e-05</td></tr><tr><td>6979</td><td>55.39361702161663</td><td>29.3297596694489</td><td>0.0</td><td>99.99373</td></tr><tr><td>6979</td><td>55.38010308450318</td><td>27.52507924657981</td><td>0.99975346</td><td>99.57009</td></tr><tr><td>6979</td><td>27.71635532979846</td><td>10.957561302597572</td><td>10.049204</td><td>9.99986</td></tr><tr><td>6979</td><td>11.710654783228941</td><td>112.48902972751874</td><td>-0.044794339</td><td>99.87924</td></tr><tr><td>6979</td><td>0.8212762098311008</td><td>0.7159796572566162</td><td>0.081416569</td><td>3.73788</td></tr><tr><td>6979</td><td>109.32461425751002</td><td>32.64901817727261</td><td>100.012024</td><td>99.99186</td></tr><tr><td>6979</td><td>107.1157367073715</td><td>32.45328517552291</td><td>100.039397</td><td>99.97344</td></tr><tr><td>6979</td><td>104.90685916307349</td><td>32.43321658606479</td><td>100.030129</td><td>99.98448</td></tr></tbody></table></div>

# %% [markdown]
# <p style="font-size: 18px; color: #f1f1f1; background: #2c3e50; padding: 15px; border-radius: 10px;">
#     📥 <strong>Resolve Missing Values and Duplicates:</strong>
# </p>
#
# <p style="font-size: 16px; color: #7f8c8d; padding: 15px;">
#     <strong><code>close</code>, <code>high</code>, <code>low</code>, <code>open</code>:</strong>
# </p>
# <p style="font-size: 16px; color: #7f8c8d; margin-left: 30px;">
#     Forward-fill is used to handle missing values in price columns. Since stock prices follow a <strong>sequential trend</strong>, using the last available value ensures continuity and avoids price jumps. This is particularly relevant on weekends or holidays when markets are closed.
# </p>

# %%
window_spec = Window.orderBy("Date").rowsBetween(Window.unboundedPreceding, 0)

df = df.withColumn("close", last("close", ignorenulls=True).over(window_spec)) \
       .withColumn("high", last("high", ignorenulls=True).over(window_spec)) \
       .withColumn("low", last("low", ignorenulls=True).over(window_spec))

# %% [markdown]
# <p style="font-size: 16px; color: #7f8c8d; padding: 15px;">
#     <strong><code>volume</code>:</strong>
# </p>
# <p style="font-size: 16px; color: #7f8c8d; margin-left: 30px;">
#     Volume is forward-filled to preserve trend consistency. In financial time series, volume spikes or drops can affect momentum indicators — forward-filling helps stabilize trend-based models.
# </p>

# %%
window_spec = Window.orderBy("Date", "Time").rowsBetween(-sys.maxsize, 0)

df = df.withColumn("volume", last("volume", ignorenulls=True).over(window_spec))

# %% [markdown]
# <p style="font-size: 16px; color: #7f8c8d; padding: 15px;">
#     <strong><code>RSI_rsi</code>, <code>SMA_sma</code>, <code>EMA_ema</code>, <code>MACD_macd</code>, <code>MACD_macd_signal</code>, <code>MACD_macd_hist</code>, <code>STOCH_slow_k</code>, <code>STOCH_slow_d</code>:</strong>
# </p>
# <p style="font-size: 16px; color: #7f8c8d; margin-left: 30px;">
#     These are momentum and trend indicators. Since they are calculated over historical windows, missing values typically occur at the beginning. We apply <strong>forward-fill</strong> to prevent disruption in pattern recognition and signal generation.
# </p>

# %%
momentum_indicators = [
    "RSI_rsi", "SMA_sma", "EMA_ema",
    "MACD_macd", "MACD_macd_signal", "MACD_macd_hist",
    "STOCH_slow_k", "STOCH_slow_d"
]

window_spec = Window.orderBy("Date", "Time").rowsBetween(-sys.maxsize, 0)
for indicator in momentum_indicators:
    df = df.withColumn(indicator, last(col(indicator), ignorenulls=True).over(window_spec))

# %% [markdown]
# <p style="font-size: 16px; color: #7f8c8d; padding: 15px;">
#     <strong><code>ADX_adx</code>, <code>CCI_cci</code>, <code>ATR_atr</code>:</strong>
# </p>
# <p style="font-size: 16px; color: #7f8c8d; margin-left: 30px;">
#     These indicators are also filled forward to maintain stability in the signals. They help identify trend strength and volatility, so maintaining consistency is essential.
# </p>

# %%
volatility_indicators = ["ADX_adx", "CCI_cci", "ATR_atr"]

window_spec = Window.orderBy("Date", "Time").rowsBetween(-sys.maxsize, 0)

for col_name in volatility_indicators:
    df = df.withColumn(col_name, last(col(col_name), ignorenulls=True).over(window_spec))

# %% [markdown]
# <p style="font-size: 16px; color: #7f8c8d; padding: 15px;">
#     <strong><code>BBANDS_upper_band</code>, <code>BBANDS_middle_band</code>, <code>BBANDS_lower_band</code>:</strong>
# </p>
# <p style="font-size: 16px; color: #7f8c8d; margin-left: 30px;">
#     Bollinger Bands depend on recent price movement. Missing values are forward-filled to ensure that volatility bands remain accurate and that trading strategies relying on band breakouts are not disrupted.
# </p>

# %%
bollinger_cols = ["BBANDS_upper_band", "BBANDS_middle_band", "BBANDS_lower_band"]

window_spec = Window.orderBy("Date", "Time").rowsBetween(-sys.maxsize, 0)

for bband in bollinger_cols:
    df = df.withColumn(bband, last(col(bband), ignorenulls=True).over(window_spec))

# %% [markdown]
# <p style="font-size: 16px; color: #7f8c8d; padding: 15px;">
#     <strong>Remove Duplicates:</strong>
# </p>
# <p style="font-size: 16px; color: #7f8c8d; margin-left: 30px;">
#     After filling missing values, we <strong>remove duplicate rows based on <code>Date</code> and <code>Time</code></strong>. This ensures each observation is unique in time and avoids bias in time-series models or visualizations.
# </p>

# %%
numeric_cols = [col_name for col_name in df.columns if col_name not in ["Date", "Time"]]

df_aggregated = df.groupBy("Date", "Time").agg(
    *[avg(col_name).alias(col_name) for col_name in numeric_cols]
)

display(df_aggregated.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Date</th><th>Time</th><th>open</th><th>high</th><th>low</th><th>close</th><th>volume</th><th>RSI_rsi</th><th>SMA_sma</th><th>EMA_ema</th><th>MACD_macd</th><th>MACD_macd_signal</th><th>MACD_macd_hist</th><th>STOCH_slow_k</th><th>STOCH_slow_d</th><th>ADX_adx</th><th>CCI_cci</th><th>ATR_atr</th><th>BBANDS_upper_band</th><th>BBANDS_middle_band</th><th>BBANDS_lower_band</th></tr></thead><tbody><tr><td>2023-05-22</td><td>09:30</td><td>30.901</td><td>31.52</td><td>30.68</td><td>31.39513</td><td>1.4546885E8</td><td>65.79526</td><td>31.31563</td><td>31.27555</td><td>0.47700234</td><td>0.54724325</td><td>-0.070240904</td><td>62.29355</td><td>64.44869</td><td>40.40849</td><td>26.16789</td><td>0.3571965</td><td>32.24575</td><td>31.029557</td><td>29.81337</td></tr><tr><td>2023-05-22</td><td>10:30</td><td>31.395</td><td>31.47</td><td>31.232</td><td>31.35269</td><td>4.867528E7</td><td>64.5589</td><td>31.27948</td><td>31.29098</td><td>0.45342475</td><td>0.52847955</td><td>-0.0750548</td><td>58.59662</td><td>61.15217</td><td>37.53837</td><td>42.34475</td><td>0.3486825</td><td>32.18723</td><td>31.10803</td><td>30.02883</td></tr><tr><td>2023-05-22</td><td>11:30</td><td>31.354</td><td>31.3683</td><td>31.183</td><td>31.239</td><td>3.806401E7</td><td>61.23924</td><td>31.28781</td><td>31.28058</td><td>0.42071598</td><td>0.50692683</td><td>-0.086210854</td><td>48.69357</td><td>56.52791</td><td>35.0044653</td><td>23.46293</td><td>0.33701252</td><td>32.12167</td><td>31.17018</td><td>30.21869</td></tr><tr><td>2023-05-22</td><td>12:30</td><td>31.236</td><td>31.304</td><td>31.15</td><td>31.2805</td><td>3.25256E7</td><td>62.0071993</td><td>31.30287</td><td>31.28057</td><td>0.39360533</td><td>0.48426253</td><td>-0.0906572</td><td>52.30835</td><td>53.19951</td><td>32.7656</td><td>11.077173</td><td>0.32394026</td><td>32.031641</td><td>31.23193</td><td>30.43222</td></tr><tr><td>2023-05-22</td><td>13:30</td><td>31.285</td><td>31.399</td><td>31.284</td><td>31.367</td><td>2.443772E7</td><td>63.62503</td><td>31.30076</td><td>31.29785</td><td>0.37477972</td><td>0.46236597</td><td>-0.087586252</td><td>59.84337</td><td>53.6151</td><td>30.52</td><td>30.64264</td><td>0.30926594</td><td>31.90152</td><td>31.29568</td><td>30.68985</td></tr></tbody></table></div>

# %% [markdown]
# <p style="font-size: 18px; color: #f1f1f1; background: #2c3e50; padding: 15px; border-radius: 10px;">
#     📥 <strong>Resolve Data Types:</strong>
# </p>

# %%
df = df.withColumn("Date", to_date(col("Date")))

df = df.withColumn("Time", to_timestamp(col("Time"), "HH:mm:ss"))

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 24px;
#     font-weight: bold;
#     text-shadow: 4px 4px 10px rgba(52, 152, 219, 0.8);
#     color: #ffffff;">
#    📆📈 Time Series Analysis 📈📆
# </div>

# %% [markdown]
# <p style="font-size: 18px; color: #f1f1f1; background: #2c3e50; padding: 15px; border-radius: 10px;">
#     📥 <strong>Prices Over Time:</strong>
# </p>
#
# <p style="font-size: 16px; color: #7f8c8d; padding: 20px; border-radius: 10px;">
#     This chart aims to identify time-based effects and patterns, allowing us to evaluate whether our forecast is reliable and consistent with historical behavior.
# </p>

# %%
df_daily = df

numeric_cols = [c for c in df.columns if c not in ["Date", "Time"]]

df_monthly = df.groupBy(date_trunc("month", col("Date")).alias("Month")) \
               .agg(*[avg(c).alias(c) for c in numeric_cols])

df_yearly = df.groupBy(year(col("Date")).alias("Year")) \
              .agg(*[avg(c).alias(c) for c in numeric_cols])

# %%
df_daily = df

df_monthly = df.groupBy(date_trunc("month", col("Date")).alias("Month")).agg(
    *[avg(c).alias(c) for c in df.columns if c not in ["Date", "Time"]]
).orderBy("Month")

df_yearly = df.groupBy(year(col("Date")).alias("Year")).agg(
    *[avg(c).alias(c) for c in df.columns if c not in ["Date", "Time"]]
).orderBy("Year")

# %%
def time_series_analysis(df_daily: pd.DataFrame, df_full: pd.DataFrame):
    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=df_daily['Date'],
        y=df_daily['close'],
        mode='lines',
        name='Daily',
        line=dict(color='#3498db', width=2.2, shape='spline', smoothing=1.2),
        visible=True
    ))

    max_date = df_full['Date'].max()

    fig.update_layout(
        updatemenus=[
            dict(
                type="buttons",
                direction="right",
                x=0,
                xanchor="left",
                y=1.15,
                yanchor="top",
                bgcolor="#34495e",
                bordercolor="#7f8c8d",
                borderwidth=1,
                font=dict(color="white", size=13),
                buttons=[
                    dict(method="relayout", label="1Y",
                         args=[{"xaxis.range": [max_date - pd.DateOffset(years=1), max_date],
                                "title": "📈 NVIDIA Closing Prices - Last 1 Year"}]),
                    dict(method="relayout", label="5Y",
                         args=[{"xaxis.range": [max_date - pd.DateOffset(years=5), max_date],
                                "title": "📈 NVIDIA Closing Prices - Last 5 Years"}]),
                    dict(method="relayout", label="10Y",
                         args=[{"xaxis.range": [max_date - pd.DateOffset(years=10), max_date],
                                "title": "📈 NVIDIA Closing Prices - Last 10 Years"}]),
                    dict(method="relayout", label="All",
                         args=[{"xaxis.autorange": True,
                                "title": "📈 NVIDIA Closing Prices Over Time"}])
                ]
            )
        ]
    )

    fig.update_layout(
        xaxis=dict(
            rangeslider=dict(visible=True, thickness=0.04),
            type="date",
            showline=True,
            linecolor="#7f8c8d"
        ),
        title=dict(
            text="📈 NVIDIA Closing Prices Over Time",
            font=dict(size=20, color="white"),
            x=0.5
        ),
        yaxis_title="Closing Price (USD)",
        plot_bgcolor="#1e272e",
        paper_bgcolor="#1e272e",
        font=dict(color="white"),
        hovermode="x unified",
        margin=dict(t=110, b=60, l=60, r=60),
        height=700
    )

    fig.show()

# %%
df_pd = df.toPandas()
df_pd["Date"] = pd.to_datetime(df_pd["Date"]) 
time_series_analysis(df_pd, df_pd)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="9807a509-096d-4854-9e4b-b52d3b6f5a0c" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9807a509-096d-4854-9e4b-b52d3b6f5a0c")) {                    Plotly.newPlot(                        "9807a509-096d-4854-9e4b-b52d3b6f5a0c",                        [{"line":{"color":"#3498db","shape":"spline","smoothing":1.2,"width":2.2},"mode":"lines","name":"Daily","visible":true,"x":["2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-22T00:00:00","2023-06-22T00:00:00","2023-06-22T00:00:00","2023-06 ...

# %% [markdown]
# <p style="font-size: 18px; color: #f1f1f1; background: #2c3e50; padding: 15px; border-radius: 10px;">
#     📥 <strong>Daily Percentage Change:</strong>
# </p>
#
# <p style="font-size: 16px; color: #7f8c8d; padding: 20px; border-radius: 10px;">
#     Analyzing the daily percentage change in stock price is important for assessing volatility and short-term changes in investor attitude. Understanding the difference in the closing price on a day-to-day basis gives indications of extreme high volatility, sudden market movements, or even a smoother change. Such information can be impactful in defining risk and guiding forecasting models to provide more accurate, data-driven predictions.
# </p>

# %%
window_spec = Window.orderBy("Date")

df = df.withColumn(
    "Daily_Change_%",
    when(
        lag("close").over(window_spec).isNotNull(),
        ((col("close") - lag("close").over(window_spec)) / lag("close").over(window_spec)) * 100
    ).otherwise(0.0)
)

# %%
def daily_change_analysis(df_pd: pd.DataFrame):
    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=df_pd['Date'],
        y=df_pd['Daily_Change_%'],
        mode='lines',
        name='Daily % Change',
        line=dict(color='#f39c12', width=2.2, shape='spline', smoothing=1.2),
        hovertemplate='📅 %{x}<br>📈 Change: %{y:.2f}%<extra></extra>'
    ))

    max_date = df_pd['Date'].max()
    fig.update_layout(
        updatemenus=[
            dict(
                type="buttons",
                direction="right",
                x=0,
                xanchor="left",
                y=1.18,
                yanchor="top",
                bgcolor="#34495e",
                bordercolor="#7f8c8d",
                borderwidth=1,
                font=dict(color="white", size=13),
                active=3,
                buttons=[
                    dict(method="relayout", label="1Y",
                         args=[{"xaxis.range": [max_date - pd.DateOffset(years=1), max_date],
                                "title": "📊 NVIDIA – Daily % Change - Last 1 Year"}]),
                    dict(method="relayout", label="5Y",
                         args=[{"xaxis.range": [max_date - pd.DateOffset(years=5), max_date],
                                "title": "📊 NVIDIA – Daily % Change - Last 5 Years"}]),
                    dict(method="relayout", label="10Y",
                         args=[{"xaxis.range": [max_date - pd.DateOffset(years=10), max_date],
                                "title": "📊 NVIDIA – Daily % Change - Last 10 Years"}]),
                    dict(method="relayout", label="All",
                         args=[{"xaxis.autorange": True,
                                "title": "📊 NVIDIA – Daily % Change Over Time"}])
                ]
            )
        ]
    )

    fig.update_layout(
        title=dict(
            text="📊 NVIDIA – Daily Percentage Change in Closing Price",
            font=dict(size=20, color="white"),
            x=0.5
        ),
        xaxis=dict(
            title="Date",
            showgrid=True,
            gridcolor="#34495e",
            showline=True,
            linecolor="#7f8c8d",
            rangeslider=dict(visible=True, thickness=0.05),
            type="date"
        ),
        yaxis=dict(
            title="Daily % Change",
            showgrid=True,
            gridcolor="#34495e",
            zeroline=True,
            zerolinewidth=1.5,
            zerolinecolor="#95a5a6"
        ),
        plot_bgcolor="#1e272e",
        paper_bgcolor="#1e272e",
        font=dict(color="white"),
        hovermode="x unified",
        margin=dict(t=110, b=60, l=60, r=60),
        height=650
    )

    fig.show()

# %%
df_pd = df.toPandas()
df_pd["Date"] = pd.to_datetime(df_pd["Date"])
daily_change_analysis(df_pd)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="c1e24290-4f8d-4882-b4b0-dfc4314e6a4a" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1e24290-4f8d-4882-b4b0-dfc4314e6a4a")) {                    Plotly.newPlot(                        "c1e24290-4f8d-4882-b4b0-dfc4314e6a4a",                        [{"hovertemplate":"\ud83d\udcc5 %{x}<br>\ud83d\udcc8 Change: %{y:.2f}%<extra></extra>","line":{"color":"#f39c12","shape":"spline","smoothing":1.2,"width":2.2},"mode":"lines","name":"Daily % Change","x":["2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00 ...

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 24px;
#     font-weight: bold;
#     text-shadow: 4px 4px 10px rgba(52, 152, 219, 0.8);
#     color: #ffffff;">
#    📈📊 Volume and Market Activity 📊📈
# </div>
# <p style="font-size: 16px; color: #7f8c8d; padding: 20px; border-radius: 10px;">
#     In order to define unusual trading volume, we employ a dynamic threshold based on the statistical distribution of each stock volume's data. Specifically, we define <code>unusual activity</code> as any volume which exceeds <strong>the average volume, plus two standard deviations</strong>:
#     <br><br>
#     <code style="color: #1abc9c; background-color: #2c3e50; padding: 3px 8px; border-radius: 5px;">threshold = mean + 2 × std</code>
# </p>
#
# <p style="font-size: 16px; color: #7f8c8d; padding: 10px 20px; border-radius: 10px;">
#     This is based on statistical reasoning: in a normal distribution, approximately 95% of the data is found within two standard deviations of the mean. By choosing this as our threshold, we will identify only the top 5% of extreme values as <strong>unusual</strong>, the true outliers.
# </p>
#
# <p style="font-size: 16px; color: #7f8c8d; padding: 10px 20px; border-radius: 10px;">
#     Spikes in trading activity generally indicate important market events like earnings releases, geopolitical news or surprise countervailing buyer or seller reactions.  Spikes will allow you to identify periods of heightened interest and possible price changes. For this reason, they are a good indicator for short-term traders as well as long-term analysts.
# </p>>

# %%
df = df.withColumn("volume", col("volume").cast("double"))
df_pd = df.toPandas()

volume_mean = df_pd["volume"].mean()
volume_std = df_pd["volume"].std()

threshold = volume_mean + 2 * volume_std

df_pd["Unusual_Volume"] = df_pd["volume"] > threshold

# %%
threshold = df_pd["volume"].mean() + 2 * df_pd["volume"].std()
df_pd["Unusual_Volume"] = df_pd["volume"] > threshold

# %%
def volume_act_analysis(df_pd: pd.DataFrame):
    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=df_pd['Date'],
        y=df_pd['volume'],
        mode='lines',
        name='Volume',
        line=dict(color='#1abc9c', width=2.2),
        hovertemplate='📅 %{x}<br>📦 Volume: %{y}<extra></extra>'
    ))

    fig.add_trace(go.Scatter(
        x=df_pd[df_pd['Unusual_Volume']]['Date'],
        y=df_pd[df_pd['Unusual_Volume']]['volume'],
        mode='markers',
        name='Unusual Activity',
        marker=dict(color='#e74c3c', size=8, symbol='circle'),
        hovertemplate='📅 %{x}<br>🚨 Unusual Volume: %{y}<extra></extra>'
    ))

    max_date = df_pd['Date'].max()
    fig.update_layout(
        updatemenus=[dict(
            type="buttons",
            direction="right",
            x=0,
            xanchor="left",
            y=1.15,
            yanchor="top",
            bgcolor="#34495e",
            bordercolor="#7f8c8d",
            borderwidth=1,
            font=dict(color="white", size=13),
            buttons=[
                dict(method="relayout", label="1Y",
                     args=[{"xaxis.range": [max_date - pd.DateOffset(years=1), max_date],
                            "title": "📊 NVIDIA – Volume Activity (1 Year)"}]),
                dict(method="relayout", label="5Y",
                     args=[{"xaxis.range": [max_date - pd.DateOffset(years=5), max_date],
                            "title": "📊 NVIDIA – Volume Activity (5 Years)"}]),
                dict(method="relayout", label="10Y",
                     args=[{"xaxis.range": [max_date - pd.DateOffset(years=10), max_date],
                            "title": "📊 NVIDIA – Volume Activity (10 Years)"}]),
                dict(method="relayout", label="All",
                     args=[{"xaxis.autorange": True,
                            "title": "📊 NVIDIA – Volume and Market Activity"}])
            ]
        )]
    )

    fig.update_layout(
        title=dict(
            text="📊 NVIDIA – Volume and Market Activity",
            font=dict(size=20, color="white"),
            x=0.5
        ),
        xaxis=dict(
            title="Date",
            showgrid=True,
            gridcolor="#34495e",
            linecolor="#7f8c8d",
            rangeslider=dict(visible=True, thickness=0.04),
            type="date"
        ),
        yaxis=dict(
            title="Trading Volume",
            showgrid=True,
            gridcolor="#34495e"
        ),
        plot_bgcolor="#1e272e",
        paper_bgcolor="#1e272e",
        font=dict(color="white"),
        hovermode="x unified",
        height=650,
        margin=dict(t=90, b=60, l=60, r=60)
    )

    fig.show()

# %%
df_pd = df_pd[["Date", "volume", "Unusual_Volume"]]
df_pd["Date"] = pd.to_datetime(df_pd["Date"])

volume_act_analysis(df_pd)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="88c185ab-cf9f-4206-a947-02094d3c72c6" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88c185ab-cf9f-4206-a947-02094d3c72c6")) {                    Plotly.newPlot(                        "88c185ab-cf9f-4206-a947-02094d3c72c6",                        [{"hovertemplate":"\ud83d\udcc5 %{x}<br>\ud83d\udce6 Volume: %{y}<extra></extra>","line":{"color":"#1abc9c","width":2.2},"mode":"lines","name":"Volume","x":["2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-26T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-02T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-09T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-16T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-22T00:00:00","2023-06-22T00:00:0 ...

# %% [markdown]
# <div style="
#     font-family: Arial, sans-serif;
#     font-size: 24px;
#     font-weight: bold;
#     text-shadow: 4px 4px 10px rgba(52, 152, 219, 0.8);
#     color: #ffffff;">
#    📥 Export the Data 📥
# </div>

# %%
# df.to_csv("../data/interim/nvidia_stock_data_update.csv")
